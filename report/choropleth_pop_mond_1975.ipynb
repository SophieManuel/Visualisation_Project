# %%
import wwstatviz

# %%
class Visualizer(object):
# Out:
#   File "<ipython-input-2-a5f2bec7a150>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
import wwstatviz

# %%
from wwstatviz import Visualizer

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\sophi\wwstatviz\wwstatviz\src\wwstatviz\visualizer.py in <module>
# ----> 1 a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv")
#
# ~\AppData\Roaming\Python\Python38\site-packages\wwstatviz\visualizer.py in __init__(self, data_path)
#      33         else:
#      34             raise ValueError('unknown data format')
# ---> 35         self._data = reader.read()
#      36
#      37     def heatmap(self, countries='all', features='all',
#
# ~\AppData\Roaming\Python\Python38\site-packages\wwstatviz\io\csvreader.py in read(self)
#      24         for e in index:
#      25             if e not in ccs:
# ---> 26                 raise ValueError(f'unknown country code {e}')
#      27         return df
#
# ValueError: unknown country code CHI

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv")

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv").histogram()

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv").histogram(countries='FRA')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\sophi\wwstatviz\wwstatviz\src\wwstatviz\visualizer.py in <module>
# ----> 1 a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv").histogram(countries='FRA')
#
# ~\AppData\Roaming\Python\Python38\site-packages\wwstatviz\visualizer.py in histogram(self, countries, features, title, xlabel, ylabel, legend)
#     169         """
#     170         fig = Figure()
# --> 171         generator = HistogramGenerator(self._data, countries, features, legend)
#     172         fig.figure = generator.generate()
#     173         fig.annotate(title=title, xlabel=xlabel, ylabel=ylabel)
#
# ~\AppData\Roaming\Python\Python38\site-packages\wwstatviz\generators\histogram.py in __init__(self, data, countries, features, legend)
#      17             raise ValueError('invalid countries argument')
# ...

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv").histogram(countries=['FRA'])

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv").histogram(countries=['FRA'], legend = True)

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv").histogram(countries=['BEL','FRA','CHN','ZWE', 'CAN'], legend = True)

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv").histogram(countries=['BEL','FRA','ZWE', 'CAN'], legend = True)

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv").histogram(countries=['CAN','BEL','FRA','ZWE'], legend = True, title='Histogram of Government expenditure education of GDP', ylabel = 'Percents')

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Government_expenditure_education_GDP.csv").histogram(countries=['BEL','FRA','ZWE','CAN'], legend = True, title='Histogram of Government expenditure education ', ylabel = 'Percents')

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Tot_Pop.csv").choropleth(countries=all, feature='1975' ,scale_feature=True, title='Total mondial population in 1975')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\sophi\wwstatviz\wwstatviz\src\wwstatviz\visualizer.py in <module>
# ----> 1 a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Tot_Pop.csv").choropleth(countries=all, feature='1975' ,scale_feature=True, title='Total mondial population in 1975')
#
# ~\AppData\Roaming\Python\Python38\site-packages\wwstatviz\visualizer.py in choropleth(self, feature, countries, scale_feature, title)
#     100         """
#     101         fig = Figure()
# --> 102         generator = ChoroplethGenerator(self._data,
#     103                                         feature, countries, scale_feature)
#     104         fig.figure = generator.generate()
#
# ~\AppData\Roaming\Python\Python38\site-packages\wwstatviz\generators\choropleth.py in __init__(self, data, feature, countries, scale_feature)
#      14         # countries
# ...

# %%
a=Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Tot_Pop.csv").choropleth(countries='all', feature='1975' ,scale_feature=True, title='Total mondial population in 1975')

# %%
a.show()
