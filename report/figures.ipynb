# %%
import wwstatviz

# %%
from wwstatviz import Visualizer

# %%
vis = Visualizer("workspace/wwstatviz/data/Government_expenditure_education_GDP.csv")

# %%
vis.histogram(countries='all', features='all', ylabel="Percents", legend=True)

# %%
a = Visualizer("workspace/wwstatviz/data/Government_expenditure_education_GDP.csv").histogram(countries=['BEL', 'FRA', 'ZWE', 'CAN'], legend=True, title='Histogram of Government expenditure education ', ylabel='Percents')

# %%
vis.line(countries=['BEL', 'ZWE', 'ESP', 'FIN', 'IND'], legend = True)

# %%
choro = Visualizer("C:/Users/sophi/wwstatviz/wwstatviz/data/Tot_Pop.csv").choropleth(countries='all', feature='1975' ,scale_feature=False, title='Total mondial population in 1975')

# %%
choro.show()
